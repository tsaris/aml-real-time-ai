# %%
import os
import sys
import tensorflow as tf
import numpy as np
import amlrealtimeai
from amlrealtimeai import resnet50

import h5py

# %matplotlib inline

# %%
import amlrealtimeai.resnet50.utils
in_images = tf.placeholder(tf.string)
image_tensors = resnet50.utils.preprocess_array(in_images)
image_tensors = tf.placeholder(tf.int32,shape=(None,224, 224, 3))

# %%
subscription_id = "80defacd-509e-410c-9812-6e52ed6a0016"
resource_group = "CMS_FPGA_Resources"
model_management_account = "CMS_FPGA_1"

from amlrealtimeai.resnet50.model import RemoteQuantizedResNet50
model_path = os.path.expanduser('~/models')
featurizer = RemoteQuantizedResNet50(subscription_id, resource_group, model_management_account, model_path)
print(featurizer.version)
# Out:
# Using TensorFlow backend.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code A2Z27UMYZ to authenticate.
# 1.1.6-rc

# %%
#from amlrealtimeai import DeploymentClient

#deployment_client = DeploymentClient(subscription_id, resource_group, model_management_account)
#services = deployment_client.list_services()
#for service in services:
#    print("Deleting: "+str(service.id))
#    deployment_client.delete_service(service.id)

featurizer.import_graph_def(include_top=False, input_tensor=image_tensors)
features = featurizer.featurizer_output

# %%
def readH5_labels(location, lmin, lmax):
    f = h5py.File(location, 'r')
    labels = np.array(f['label'])
    labels = labels.reshape(labels.shape[0])
    labels = labels[lmin:lmax]
    return labels
    
def readNumpy_size(location):
    feature_results = np.load(location)
    return feature_results
    
    
labels_0  = readH5_labels("//Users/atsaris/mygit_repos/ml_service/datasets/HDF5Images/train_100K.h5", 0,      10000)
labels_1  = readH5_labels("//Users/atsaris/mygit_repos/ml_service/datasets/HDF5Images/train_100K.h5", 10000,  15000)
labels_2  = readH5_labels("//Users/atsaris/mygit_repos/ml_service/datasets/HDF5Images/train_100K.h5", 15000,  20000)
labels_3  = readH5_labels("//Users/atsaris/mygit_repos/ml_service/datasets/HDF5Images/train_100K.h5", 20000,  25000)
labels_4  = readH5_labels("//Users/atsaris/mygit_repos/ml_service/datasets/HDF5Images/train_100K.h5", 25000,  30000)
labels_5  = readH5_labels("//Users/atsaris/mygit_repos/ml_service/datasets/HDF5Images/train_100K.h5", 30000,  35000)
labels_6  = readH5_labels("//Users/atsaris/mygit_repos/ml_service/datasets/HDF5Images/train_100K.h5", 35000,  50000)
labels_7  = readH5_labels("//Users/atsaris/mygit_repos/ml_service/datasets/HDF5Images/train_100K.h5", 50000,  70000)
labels_8  = readH5_labels("//Users/atsaris/mygit_repos/ml_service/datasets/HDF5Images/train_100K.h5", 70000,  90000)
labels_9  = readH5_labels("//Users/atsaris/mygit_repos/ml_service/datasets/HDF5Images/train_100K.h5", 90000,  100000)
labels_10 = readH5_labels("//Users/atsaris/mygit_repos/ml_service/datasets/HDF5Images/train_100K.h5", 100000, 110000)
labels_11 = readH5_labels("//Users/atsaris/mygit_repos/ml_service/datasets/HDF5Images/train_100K.h5", 110000, 120000)
labels_12 = readH5_labels("//Users/atsaris/mygit_repos/ml_service/datasets/HDF5Images/train_100K.h5", 120000, 130000)
labels_13 = readH5_labels("//Users/atsaris/mygit_repos/ml_service/datasets/HDF5Images/train_100K.h5", 130000, 150000)
labels_14 = readH5_labels("//Users/atsaris/mygit_repos/ml_service/datasets/HDF5Images/train_100K.h5", 150000, 170000)
labels_15 = readH5_labels("//Users/atsaris/mygit_repos/ml_service/datasets/HDF5Images/train_100K.h5", 170000, 190000)
labels_16 = readH5_labels("//Users/atsaris/mygit_repos/ml_service/datasets/HDF5Images/train_100K.h5", 190000, 200000)


feature_results_0  = readNumpy_size("nova_features/features_nova_10000.npy")
feature_results_1 = readNumpy_size("nova_features/features_nova_15000.npy")
feature_results_2  = readNumpy_size("nova_features/features_nova_20000.npy")
feature_results_3  = readNumpy_size("nova_features/features_nova_25000.npy")
feature_results_4  = readNumpy_size("nova_features/features_nova_30000.npy")
feature_results_5  = readNumpy_size("nova_features/features_nova_35000.npy")
feature_results_6  = readNumpy_size("nova_features/features_nova_50000.npy")
feature_results_7  = readNumpy_size("nova_features/features_nova_70000.npy")
feature_results_8  = readNumpy_size("nova_features/features_nova_90000.npy")
feature_results_9  = readNumpy_size("nova_features/features_nova_100000.npy")
feature_results_10  = readNumpy_size("nova_features/features_nova_110000.npy")
feature_results_11  = readNumpy_size("nova_features/features_nova_120000.npy")
feature_results_12  = readNumpy_size("nova_features/features_nova_130000.npy")
feature_results_13  = readNumpy_size("nova_features/features_nova_150000.npy")
feature_results_14 = readNumpy_size("nova_features/features_nova_170000.npy")
feature_results_15 = readNumpy_size("nova_features/features_nova_190000.npy")
feature_results_16 = readNumpy_size("nova_features/features_nova_200000.npy")


feature_results = np.concatenate((feature_results_0, feature_results_1,
                                      feature_results_2,feature_results_3,
                                      feature_results_4,feature_results_5,
                                      feature_results_6,feature_results_7,
                                      feature_results_8,feature_results_9,
                                      feature_results_10,feature_results_11,
                                      feature_results_12,feature_results_13,
                                      feature_results_14,feature_results_15,
                                 feature_results_16))
labels = np.concatenate((labels_0, labels_1,
                                    labels_2,labels_3,
                                      labels_4,labels_5,
                                      labels_6,labels_7,
                                      labels_8,labels_9,
                                      labels_10,labels_11,
                                      labels_12,labels_13,
                                      labels_14,labels_15,
                                    labels_16)) 
                                    



#print(feature_results.shape)

# %%
from keras.models import Sequential
from keras.layers import Dropout, Dense, Flatten
from keras import optimizers

FC_SIZE = 1024
NUM_CLASSES = 5

model = Sequential()
model.add(Dropout(0.2, input_shape=(1, 1, 2048,)))
model.add(Dense(FC_SIZE, activation='relu', input_dim=(1, 1, 2048,)))
model.add(Flatten())
model.add(Dense(NUM_CLASSES, activation='sigmoid', input_dim=FC_SIZE))

model.compile(optimizer=optimizers.SGD(lr=1e-4,momentum=0.9), loss='binary_crossentropy', metrics=['accuracy'])

# %%
from sklearn.model_selection import train_test_split
from keras.utils import np_utils

onehot_labels = np_utils.to_categorical(labels)
X_train, X_test, y_train, y_test = train_test_split(feature_results, onehot_labels, random_state=42, shuffle=True)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (150000, 1, 1, 2048) (50000, 1, 1, 2048) (150000, 5) (50000, 5)

# %%
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 150000/150000 [==============================] - 41s 271us/step - loss: 0.3937 - acc: 0.8244
# Epoch 2/100
# 150000/150000 [==============================] - 43s 288us/step - loss: 0.3623 - acc: 0.8400
# Epoch 3/100
# 150000/150000 [==============================] - 44s 292us/step - loss: 0.3512 - acc: 0.8456
# Epoch 4/100
# 150000/150000 [==============================] - 44s 295us/step - loss: 0.3441 - acc: 0.8490
# Epoch 5/100
# 150000/150000 [==============================] - 45s 300us/step - loss: 0.3386 - acc: 0.8516
# Epoch 6/100
# 150000/150000 [==============================] - 44s 291us/step - loss: 0.3342 - acc: 0.8542
# Epoch 7/100
# 150000/150000 [==============================] - 43s 286us/step - loss: 0.3305 - acc: 0.8556
# Epoch 8/100
# 150000/150000 [==============================] - 42s 280us/step - loss: 0.3276 - acc: 0.8575
# Epoch 9/100
# 150000/150000 [==============================] - 42s 280us/step - loss: 0.3252 - acc: 0.8586
# Epoch 10/100
# ...

# %%
from numpy import argmax

y_probs = model.predict(X_test)
y_prob_max = np.argmax(y_probs, 1)
y_test_max = np.argmax(y_test, 1)
print(y_probs)
print(y_prob_max)
print(y_test_max)
# Out:
# [[2.0658800e-03 9.4939327e-01 1.5491046e-02 2.9420068e-03 1.3529946e-02]
#  [1.7763138e-01 4.8883114e-02 4.5414084e-01 2.9607126e-01 5.9108514e-09]
#  [5.7186674e-02 1.0048056e-01 9.1590751e-03 5.7778817e-01 3.1415349e-01]
#  ...
#  [1.6432928e-01 2.0789351e-01 1.7886970e-02 6.4495766e-01 3.0197412e-02]
#  [2.5444099e-01 2.3281424e-01 1.6519334e-02 5.1049143e-01 2.8700665e-02]
#  [1.0598644e-01 7.9409468e-01 7.3923342e-02 1.5466405e-01 1.5707024e-04]]
# [1 2 3 ... 3 3 1]
# [1 2 3 ... 3 0 1]

# %%
from sklearn.metrics import confusion_matrix, roc_auc_score, accuracy_score, precision_score, recall_score, f1_score
import itertools
import matplotlib
from matplotlib import pyplot as plt

# compute a bunch of classification metrics 
def classification_metrics(y_true, y_pred, y_prob):
    cm_dict = {}
    cm_dict['Accuracy'] = accuracy_score(y_true, y_pred)
    cm_dict['Precision'] =  precision_score(y_true, y_pred, average=None)
    cm_dict['Recall'] =  recall_score(y_true, y_pred, average=None)
    cm_dict['F1'] =  f1_score(y_true, y_pred, average=None) 
    #cm_dict['AUC'] = roc_auc_score(y_true, y_prob[:,0])
    cm_dict['Confusion Matrix'] = confusion_matrix(y_true, y_pred).tolist()
    return cm_dict

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    """Plots a confusion matrix.
    Source: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
    New BSD License - see appendix
    """
    cm_max = cm.max()
    cm_min = cm.min()
    if cm_min > 0: cm_min = 0
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm_max = 1
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    thresh = cm_max / 2.
    plt.clim(cm_min, cm_max)

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i,
                 round(cm[i, j], 3),  # round to 3 decimals if they are float
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    
cm_dict = classification_metrics(y_test_max, y_prob_max, y_probs)
for m in cm_dict:
    print(m, cm_dict[m])
cm = np.asarray(cm_dict['Confusion Matrix'])
plot_confusion_matrix(cm, ['numu','nue','nutau','nc','cosmic'], normalize=False)
# Out:
# Accuracy 0.71108
# Precision [0.67405468 0.83511154 0.40391459 0.66937445 0.88378766]
# Recall [0.76603695 0.69943136 0.20524412 0.74720869 0.83018868]
# F1 [0.71710825 0.76127321 0.27218225 0.70615326 0.8561501 ]
# Confusion Matrix [[11070, 421, 335, 2597, 28], [1363, 8610, 126, 1919, 292], [1088, 403, 681, 1143, 3], [2862, 610, 544, 12113, 82], [40, 266, 0, 324, 3080]]
